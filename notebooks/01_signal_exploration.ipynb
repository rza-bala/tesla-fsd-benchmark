# %%
import pandas as pd
from pathlib import Path

# %%
INTERIM_DIR = Path("../data/interim")
REGISTRY_DIR = Path("../config/registry/")

# %%
# List all per-DBC Parquet files for the first log (or loop over all logs)
files = sorted(INTERIM_DIR.glob("*.parquet"))
print("Available decoded files:", [f.name for f in files])
# Out:
# Available decoded files: ['00000001_can1_can.parquet', '00000001_can1_party.parquet', '00000001_can1_vehicle.parquet', '00000001_can9_internal.parquet', '00000002_can1_can.parquet', '00000002_can1_party.parquet', '00000002_can1_vehicle.parquet', '00000002_can9_internal.parquet', '00000003_can1_can.parquet', '00000003_can1_party.parquet', '00000003_can1_vehicle.parquet', '00000003_can9_internal.parquet']

# %%
# --- Company standard: export and print all signals from all decoded files ---
all_signals = {}

for pq in sorted(INTERIM_DIR.glob("*.parquet")):
    df = pd.read_parquet(pq)
    col_list = list(df.columns)
    
    # Print all columns, one per line (no truncation)
    print(f"\nSignals in: {pq.name}")
    for c in col_list:
        print(c)
    
    # Save to CSV for full review (one file per parquet, or aggregate if you want)
    pd.DataFrame({"signal": col_list}).to_csv(pq.with_suffix(".columns.csv"), index=False)
    
    # Store for aggregate review
    all_signals[pq.name] = col_list
# Out:
# Signals in: 00000001_can1_can.parquet
# time
# arbitration_id
# SDM_bcklDrivStatus_can1_can
# SDM_bcklPassStatus_can1_can
# UI_autopilotControlRequest_can1_can
# UI_ulcStalkConfirm_can1_can
# UI_summonHeartbeat_can1_can
# UI_curvSpeedAdaptDisable_can1_can
# UI_dasDeveloper_can1_can
# UI_enableVinAssociation_can1_can
# UI_lssLkaEnabled_can1_can
# UI_lssLdwEnabled_can1_can
# UI_autoSummonEnable_can1_can
# UI_exceptionListEnable_can1_can
# UI_roadCheckDisable_can1_can
# UI_driveOnMapsEnable_can1_can
# UI_handsOnRequirementDisable_can1_can
# UI_forksEnable_can1_can
# UI_fuseLanesDisable_can1_can
# UI_fuseHPPDisable_can1_can
# UI_fuseVehiclesDisable_can1_can
# UI_enableNextGenACC_can1_can
# UI_visionSpeedType_can1_can
# UI_curvatureDatabaseOnly_can1_can
# UI_lssElkEnabled_can1_can
# UI_summonExitType_can1_can
# UI_summonEntryType_can1_can
# UI_selfParkRequest_can1_can
# UI_summonReverseDist_can1_can
# UI_undertakeAssistEnable_can1_can
# UI_adaptiveSetSpeedEnable_can1_can
# UI_drivingSide_can1_can
# UI_enableClipTelemetry_can1_can
# UI_enableTripTelemetry_can1_can
# UI_enableRoadSegmentTelemetry_can1_can
# UI_followNavRouteEnable_can1_can
# UI_ulcSpeedConfig_can1_can
# UI_ulcBlindSpotConfig_can1_can
# UI_autopilotAlwaysOn_can1_can
# UI_accFromZero_can1_can
# UI_alcOffHighwayEnable_can1_can
# UI_validationLoop_can1_can
# UI_ulcOffHighway_can1_can
# UI_enableNavRouteCSA_can1_can
# UI_enableCutinExperiments_can1_can
# UI_source3D_can1_can
# UI_enableVisionOnlyStops_can1_can
# UI_mapSpeedLimitDependency_can1_can
# UI_roadClass_can1_can
# UI_inSuperchargerGeofence_can1_can
# UI_mapSpeedUnits_can1_can
# UI_mapSpeedLimit_can1_can
# UI_mapSpeedLimitType_can1_can
# UI_countryCode_can1_can
# UI_streetCount_can1_can
# UI_gpsRoadMatch_can1_can
# UI_navRouteActive_can1_can
# UI_parallelAutoparkEnabled_can1_can
# UI_perpendicularAutoparkEnabled_can1_can
# UI_nextBranchDist_can1_can
# UI_controlledAccess_can1_can
# UI_nextBranchLeftOffRamp_can1_can
# UI_nextBranchRightOffRamp_can1_can
# UI_rejectLeftLane_can1_can
# UI_rejectRightLane_can1_can
# UI_rejectHPP_can1_can
# UI_rejectNav_can1_can
# UI_rejectLeftFreeSpace_can1_can
# UI_rejectRightFreeSpace_can1_can
# UI_rejectAutosteer_can1_can
# UI_rejectHandsOn_can1_can
# UI_acceptBottsDots_can1_can
# UI_autosteerRestricted_can1_can
# UI_pmmEnabled_can1_can
# UI_scaEnabled_can1_can
# UI_mapDataCounter_can1_can
# UI_mapDataChecksum_can1_can
# UI_csaRoadCurvC2_can1_can
# UI_csaRoadCurvC3_can1_can
# UI_csaRoadCurvRange_can1_can
# UI_csaRoadCurvCounter_can1_can
# UI_csaRoadCurvUsingTspline_can1_can
# UI_csaRoadCurvReserved_can1_can
# UI_csaRoadCurvChecksum_can1_can
# YEAR_can1_can
# CERRD_can1_can
# MONTH_can1_can
# DOOR_STATE_FL_can1_can
# DOOR_STATE_FR_can1_can
# SECOND_can1_can
# DOOR_STATE_RL_can1_can
# Hour_can1_can
# DOOR_STATE_RR_can1_can
# DAY_can1_can
# MINUTE_can1_can
# BOOT_STATE_can1_can
# GTW_updateInProgress_can1_can
# BC_headLightLStatus_can1_can
# DOOR_STATE_FrontTrunk_can1_can
# MCU_transportModeOn_can1_can
# MCU_factoryMode_can1_can
# BC_indicatorRStatus_can1_can
# BC_indicatorLStatus_can1_can
# BC_headLightRStatus_can1_can
# DAS_headlightRequest_can1_can
# DAS_hazardLightRequest_can1_can
# DAS_wiperSpeed_can1_can
# DAS_turnIndicatorRequest_can1_can
# DAS_highLowBeamDecision_can1_can
# DAS_highLowBeamOffReason_can1_can
# DAS_turnIndicatorRequestReason_can1_can
# DAS_bodyControlsCounter_can1_can
# DAS_bodyControlsChecksum_can1_can
# DI_torqueEstimate_can1_can
# DI_gear_can1_can
# DI_brakePedal_can1_can
# DI_vehicleSpeed_can1_can
# DI_gearRequest_can1_can
# DI_torqueInterfaceFailure_can1_can
# DI_torque2Counter_can1_can
# DI_brakePedalState_can1_can
# DI_epbParkRequest_can1_can
# DI_epbInterfaceReady_can1_can
# DI_torque2Checksum_can1_can
# DI_torqueDriver_can1_can
# DI_torque1Counter_can1_can
# DI_torqueMotor_can1_can
# DI_soptState_can1_can
# DI_motorRPM_can1_can
# DI_pedalPos_can1_can
# DI_torque1Checksum_can1_can
# DI_systemState_can1_can
# DI_vehicleHoldState_can1_can
# DI_proximity_can1_can
# DI_driveReady_can1_can
# DI_regenLight_can1_can
# DI_state_can1_can
# DI_cruiseState_can1_can
# DI_analogSpeed_can1_can
# DI_immobilizerState_can1_can
# DI_speedUnits_can1_can
# DI_cruiseSet_can1_can
# DI_aebState_can1_can
# DI_stateCounter_can1_can
# DI_digitalSpeed_can1_can
# DI_stateChecksum_can1_can
# MCU_clusterReadyForPowerOff_can1_can
# MCU_clusterReadyForDrive_can1_can
# MCU_clusterBacklightOn_can1_can
# MCU_clusterBrightnessLevel_can1_can
#
# Signals in: 00000001_can1_party.parquet
# time
# arbitration_id
# SCCM_steeringAngleCrc_can1_party
# SCCM_steeringAngleCounter_can1_party
# SCCM_supplierID_can1_party
# SCCM_steeringAngleSensorStatus_can1_party
# SCCM_steeringAngle_can1_party
# SCCM_steeringAngleValidity_can1_party
# SCCM_steeringAngleSpeed_can1_party
# SCCM_steeringAngleSensorReservd1_can1_party
# SCCM_steeringAngleSensorReservd2_can1_party
# SCCM_steeringAngleSensorReservd3_can1_party
# IBST_statusChecksum_can1_party
# IBST_statusCounter_can1_party
# IBST_iBoosterStatus_can1_party
# IBST_driverBrakeApply_can1_party
# IBST_internalState_can1_party
# IBST_sInputRodDriver_can1_party
# VCFRONT_LVPowerStateIndex_can1_party
# VCFRONT_vehiclePowerState_can1_party
# VCFRONT_LVPowerStateCounter_can1_party
# VCFRONT_LVPowerStateChecksum_can1_party
# VCFRONT_parkLVState_can1_party
# VCFRONT_espLVState_can1_party
# VCFRONT_radcLVState_can1_party
# VCFRONT_hvacCompLVState_can1_party
# VCFRONT_ptcLVRequest_can1_party
# VCFRONT_sccmLVRequest_can1_party
# VCFRONT_tpmsLVRequest_can1_party
# VCFRONT_rcmLVRequest_can1_party
# VCFRONT_iBoosterLVState_can1_party
# VCFRONT_tunerLVRequest_can1_party
# VCFRONT_amplifierLVRequest_can1_party
# VCFRONT_das1HighCurrentLVState_can1_party
# VCFRONT_das2HighCurrentLVState_can1_party
# VCFRONT_diLVRequest_can1_party
# VCFRONT_disLVState_can1_party
# VCFRONT_oilPumpFrontLVState_can1_party
# VCFRONT_oilPumpRearLVRequest_can1_party
# VCFRONT_ocsLVRequest_can1_party
# VCFRONT_vcleftHiCurrentLVState_can1_party
# VCFRONT_vcrightHiCurrentLVState_can1_party
# VCFRONT_uiHiCurrentLVState_can1_party
# VCFRONT_uiAudioLVState_can1_party
# SCCM_leftStalkCrc_can1_party
# SCCM_leftStalkCounter_can1_party
# SCCM_highBeamStalkStatus_can1_party
# SCCM_washWipeButtonStatus_can1_party
# SCCM_turnIndicatorStalkStatus_can1_party
# SCCM_leftStalkReserved1_can1_party
# DAS_stopLineDist_can1_party
# DAS_trafficLightColor_can1_party
# APS_eacAllow_can1_party
# APS_eacMonitorCounter_can1_party
# APS_eacMonitorChecksum_can1_party
# VCFRONT_cpLVRequest_can1_party
# VCFRONT_epasLVState_can1_party
# VCFRONT_hvcLVRequest_can1_party
# VCFRONT_tasLVState_can1_party
# VCFRONT_pcsLVState_can1_party
# APS_appStatusMonitorState_can1_party
# APS_vehBehaviorState_can1_party
# APS_canMaster_can1_party
# APS_appGpioState_can1_party
# APS_eacInternalState_can1_party
# APS_switchState_can1_party
# APS_apbStatusMonitorState_can1_party
# APS_apbGpioState_can1_party
# APS_statusCounter_can1_party
# DAS_offRoadAssist_can1_party
# DAS_slipStart_can1_party
# DAS_driverSteeringWeight_can1_party
# DAS_distanceUnits_can1_party
# DAS_aebEnabled_can1_party
# DAS_adaptiveHeadlights_can1_party
# DAS_autosteerEnabled2_can1_party
# DAS_autosteerEnabled_can1_party
# DAS_fcwSensitivity_can1_party
# DAS_fcwEnabled_can1_party
# DAS_driverAccelerationMode_can1_party
# DAS_obstacleAwareAcceleration_can1_party
# DAS_settingCounter_can1_party
# DAS_settingChecksum_can1_party
# DI_systemStatusChecksum_can1_party
# DI_systemStatusCounter_can1_party
# DI_systemState_can1_party
# DI_brakePedalState_can1_party
# DI_gear_can1_party
# DI_regenLight_can1_party
# DI_immobilizerState_can1_party
# DI_accelPedalPos_can1_party
# DI_tractionControlMode_can1_party
# DI_epbRequest_can1_party
# DI_proximity_can1_party
# DI_keepAliveRequest_can1_party
# DI_trackModeState_can1_party
# DI_torqueChecksum_can1_party
# DI_torqueCounter_can1_party
# DI_torqueCommand_can1_party
# DI_torqueActual_can1_party
# DI_axleSpeed_can1_party
# DI_speedChecksum_can1_party
# DI_speedCounter_can1_party
# DI_vehicleSpeed_can1_party
# DI_uiSpeed_can1_party
# DI_uiSpeedUnits_can1_party
#
# Signals in: 00000001_can1_vehicle.parquet
# time
# arbitration_id
# SCCM_steeringAngleCrc_can1_vehicle
# SCCM_steeringAngleCounter_can1_vehicle
# SCCM_supplierID_can1_vehicle
# SCCM_steeringAngleSensorStatus_can1_vehicle
# SCCM_steeringAngle_can1_vehicle
# SCCM_steeringAngleValidity_can1_vehicle
# SCCM_steeringAngleSpeed_can1_vehicle
# SCCM_steeringAngleSensorReservd1_can1_vehicle
# SCCM_steeringAngleSensorReservd2_can1_vehicle
# SCCM_steeringAngleSensorReservd3_can1_vehicle
# VCLEFT_switchStatusIndex_can1_vehicle
# VCLEFT_swcLeftTiltRight_can1_vehicle
# VCLEFT_swcLeftPressed_can1_vehicle
# VCLEFT_swcRightTiltLeft_can1_vehicle
# VCLEFT_swcRightTiltRight_can1_vehicle
# VCLEFT_swcRightPressed_can1_vehicle
# VCLEFT_swcLeftTiltLeft_can1_vehicle
# VCLEFT_swcLeftScrollTicks_can1_vehicle
# VCLEFT_swcRightScrollTicks_can1_vehicle
# VCLEFT_btnWindowUpLR_can1_vehicle
# VCLEFT_btnWindowAutoUpLR_can1_vehicle
# VCLEFT_btnWindowDownLR_can1_vehicle
# VCLEFT_btnWindowAutoDownLR_can1_vehicle
# VCRIGHT_loadShedPriority_can1_vehicle
# VCRIGHT_vehiclePowerStateDBG_can1_vehicle
# VCRIGHT_swEnStatus_can1_vehicle
# VCRIGHT_rearDefrostState_can1_vehicle
# VCRIGHT_mirrorHeatState_can1_vehicle
# VCRIGHT_OTAState_can1_vehicle
# VCRIGHT_5AVoltage_can1_vehicle
# VCRIGHT_vbatProt_can1_vehicle
# VCRIGHT_footwellLightCurrent_can1_vehicle
# VCRIGHT_pcbaTemperature_can1_vehicle
# VCLEFT_frontLatchStatus_can1_vehicle
# VCLEFT_rearLatchStatus_can1_vehicle
# VCLEFT_frontLatchSwitch_can1_vehicle
# VCLEFT_rearLatchSwitch_can1_vehicle
# VCLEFT_frontHandlePulled_can1_vehicle
# VCLEFT_rearHandlePulled_can1_vehicle
# VCLEFT_frontRelActuatorSwitch_can1_vehicle
# VCLEFT_rearRelActuatorSwitch_can1_vehicle
# VCLEFT_frontHandlePWM_can1_vehicle
# VCLEFT_rearHandlePWM_can1_vehicle
# VCLEFT_frontIntSwitchPressed_can1_vehicle
# VCLEFT_rearIntSwitchPressed_can1_vehicle
# VCLEFT_mirrorTiltXPosition_can1_vehicle
# VCLEFT_mirrorTiltYPosition_can1_vehicle
# VCLEFT_mirrorState_can1_vehicle
# VCLEFT_mirrorFoldState_can1_vehicle
# VCLEFT_mirrorRecallState_can1_vehicle
# VCLEFT_mirrorHeatState_can1_vehicle
# VCLEFT_mirrorDipped_can1_vehicle
# VCLEFT_frontHandlePulledPersist_can1_vehicle
# VCFRONT_indicatorLeftRequest_can1_vehicle
# VCFRONT_indicatorRightRequest_can1_vehicle
# VCFRONT_hazardLightRequest_can1_vehicle
# VCFRONT_ambientLightingBrightnes_can1_vehicle
# VCFRONT_switchLightingBrightness_can1_vehicle
# VCFRONT_courtesyLightingRequest_can1_vehicle
# VCFRONT_approachLightingRequest_can1_vehicle
# VCFRONT_seeYouHomeLightingReq_can1_vehicle
# VCFRONT_hazardSwitchBacklight_can1_vehicle
# VCFRONT_lowBeamLeftStatus_can1_vehicle
# VCFRONT_lowBeamRightStatus_can1_vehicle
# VCFRONT_highBeamLeftStatus_can1_vehicle
# VCFRONT_highBeamRightStatus_can1_vehicle
# VCFRONT_DRLLeftStatus_can1_vehicle
# VCFRONT_DRLRightStatus_can1_vehicle
# VCFRONT_fogLeftStatus_can1_vehicle
# VCFRONT_fogRightStatus_can1_vehicle
# VCFRONT_sideMarkersStatus_can1_vehicle
# VCFRONT_sideRepeaterLeftStatus_can1_vehicle
# VCFRONT_sideRepeaterRightStatus_can1_vehicle
# VCFRONT_turnSignalLeftStatus_can1_vehicle
# VCFRONT_turnSignalRightStatus_can1_vehicle
# VCFRONT_parkLeftStatus_can1_vehicle
# VCFRONT_parkRightStatus_can1_vehicle
# VCFRONT_highBeamSwitchActive_can1_vehicle
# VCFRONT_simLatchingStalk_can1_vehicle
# VCFRONT_lowBeamsOnForDRL_can1_vehicle
# VCFRONT_lowBeamsCalibrated_can1_vehicle
# SCCM_rightStalkCrc_can1_vehicle
# SCCM_rightStalkCounter_can1_vehicle
# SCCM_rightStalkStatus_can1_vehicle
# SCCM_rightStalkReserved1_can1_vehicle
# SCCM_parkButtonStatus_can1_vehicle
# SCCM_rightStalkReserved2_can1_vehicle
# SCCM_leftStalkCrc_can1_vehicle
# SCCM_leftStalkCounter_can1_vehicle
# SCCM_highBeamStalkStatus_can1_vehicle
# SCCM_washWipeButtonStatus_can1_vehicle
# SCCM_turnIndicatorStalkStatus_can1_vehicle
# SCCM_leftStalkReserved1_can1_vehicle
# VCLEFT_hornSwitchPressed_can1_vehicle
# VCLEFT_hazardButtonPressed_can1_vehicle
# VCLEFT_driverPresent_can1_vehicle
# VCLEFT_rightMirrorTilt_can1_vehicle
# VCLEFT_frontSeatTrackBack_can1_vehicle
# VCLEFT_frontSeatTrackForward_can1_vehicle
# VCLEFT_frontSeatTiltDown_can1_vehicle
# VCLEFT_frontSeatTiltUp_can1_vehicle
# VCLEFT_frontSeatLiftDown_can1_vehicle
# VCLEFT_frontSeatLiftUp_can1_vehicle
# VCLEFT_frontSeatBackrestBack_can1_vehicle
# VCLEFT_frontSeatBackrestForward_can1_vehicle
# VCLEFT_frontSeatLumbarDown_can1_vehicle
# VCLEFT_frontSeatLumbarUp_can1_vehicle
# VCLEFT_frontSeatLumbarIn_can1_vehicle
# VCLEFT_frontSeatLumbarOut_can1_vehicle
# VCLEFT_btnWindowSwPackUpLF_can1_vehicle
# VCLEFT_btnWindowSwPackAutoUpLF_can1_vehicle
# VCLEFT_btnWindowSwPackDownLF_can1_vehicle
# VCLEFT_btnWindowSwPackAutoDownLF_can1_vehicle
# VCLEFT_btnWindowSwPackUpLR_can1_vehicle
# VCLEFT_btnWindowSwPackAutoUpLR_can1_vehicle
# VCLEFT_btnWindowSwPackDownLR_can1_vehicle
# VCLEFT_btnWindowSwPackAutoDownLR_can1_vehicle
# VCLEFT_btnWindowSwPackUpRF_can1_vehicle
# VCLEFT_btnWindowSwPackAutoUpRF_can1_vehicle
# VCLEFT_btnWindowSwPackDownRF_can1_vehicle
# VCLEFT_btnWindowSwPackAutoDownRF_can1_vehicle
# VCLEFT_btnWindowSwPackUpRR_can1_vehicle
# VCLEFT_btnWindowSwPackAutoUpRR_can1_vehicle
# VCLEFT_btnWindowSwPackDownRR_can1_vehicle
# VCLEFT_btnWindowSwPackAutoDownRR_can1_vehicle
# VCLEFT_frontBuckleSwitch_can1_vehicle
# VCLEFT_frontOccupancySwitch_can1_vehicle
# VCLEFT_rearLeftBuckleSwitch_can1_vehicle
# VCLEFT_rearCenterOccupancySwitch_can1_vehicle
# VCLEFT_rearLeftOccupancySwitch_can1_vehicle
# VCLEFT_rearRightOccupancySwitch_can1_vehicle
# VCLEFT_brakePressed_can1_vehicle
# VCLEFT_rearHVACButtonPressed_can1_vehicle
# VCRIGHT_frontLatchStatus_can1_vehicle
# VCRIGHT_rearLatchStatus_can1_vehicle
# VCRIGHT_frontLatchSwitch_can1_vehicle
# VCRIGHT_rearLatchSwitch_can1_vehicle
# VCRIGHT_frontHandlePulled_can1_vehicle
# VCRIGHT_rearHandlePulled_can1_vehicle
# VCRIGHT_frontRelActuatorSwitch_can1_vehicle
# VCRIGHT_rearRelActuatorSwitch_can1_vehicle
# VCRIGHT_frontHandlePWM_can1_vehicle
# VCRIGHT_rearHandlePWM_can1_vehicle
# VCRIGHT_reservedForBackCompat_can1_vehicle
# VCRIGHT_frontHandlePulledPersist_can1_vehicle
# VCRIGHT_frontIntSwitchPressed_can1_vehicle
# VCRIGHT_rearIntSwitchPressed_can1_vehicle
# VCRIGHT_mirrorTiltXPosition_can1_vehicle
# VCRIGHT_mirrorTiltYPosition_can1_vehicle
# VCRIGHT_mirrorState_can1_vehicle
# VCRIGHT_mirrorFoldState_can1_vehicle
# VCRIGHT_trunkLatchStatus_can1_vehicle
# VCRIGHT_mirrorRecallState_can1_vehicle
# VCRIGHT_mirrorDipped_can1_vehicle
# DAS_headlightRequest_can1_vehicle
# DAS_hazardLightRequest_can1_vehicle
# DAS_wiperSpeed_can1_vehicle
# DAS_turnIndicatorRequest_can1_vehicle
# DAS_highLowBeamDecision_can1_vehicle
# DAS_heaterRequest_can1_vehicle
# DAS_turnIndicatorRequestReason_can1_vehicle
# DAS_autopilotActive_can1_vehicle
# DAS_accActive_can1_vehicle
# DAS_bodyControlsCounter_can1_vehicle
# DAS_bodyControlsChecksum_can1_vehicle
# SpdCtrlLvr_Stat_can1_vehicle
# VSL_Enbl_Rq_can1_vehicle
# SpdCtrlLvrStat_Inv_can1_vehicle
# DTR_Dist_Rq_can1_vehicle
# TurnIndLvr_Stat_can1_vehicle
# HiBmLvr_Stat_can1_vehicle
# WprWashSw_Psd_can1_vehicle
# WprWash_R_Sw_Posn_V2_can1_vehicle
# StW_Lvr_Stat_can1_vehicle
# StW_Cond_Flt_can1_vehicle
# StW_Cond_Psd_can1_vehicle
# HrnSw_Psd_can1_vehicle
# StW_Sw00_Psd_can1_vehicle
# StW_Sw01_Psd_can1_vehicle
# StW_Sw02_Psd_can1_vehicle
# StW_Sw03_Psd_can1_vehicle
# StW_Sw04_Psd_can1_vehicle
# StW_Sw05_Psd_can1_vehicle
# StW_Sw06_Psd_can1_vehicle
# StW_Sw07_Psd_can1_vehicle
# StW_Sw08_Psd_can1_vehicle
# StW_Sw09_Psd_can1_vehicle
# StW_Sw10_Psd_can1_vehicle
# StW_Sw11_Psd_can1_vehicle
# StW_Sw12_Psd_can1_vehicle
# StW_Sw13_Psd_can1_vehicle
# StW_Sw14_Psd_can1_vehicle
# StW_Sw15_Psd_can1_vehicle
# WprSw6Posn_can1_vehicle
# MC_STW_ACTN_RQ_can1_vehicle
# CRC_STW_ACTN_RQ_can1_vehicle
# DI_systemStatusChecksum_can1_vehicle
# DI_systemStatusCounter_can1_vehicle
# DI_systemState_can1_vehicle
# DI_brakePedalState_can1_vehicle
# DI_gear_can1_vehicle
# DI_regenLight_can1_vehicle
# DI_immobilizerState_can1_vehicle
# DI_accelPedalPos_can1_vehicle
# DI_tractionControlMode_can1_vehicle
# DI_epbRequest_can1_vehicle
# DI_proximity_can1_vehicle
# DI_keepAliveRequest_can1_vehicle
# DI_trackModeState_can1_vehicle
#
# Signals in: 00000001_can9_internal.parquet
# time
# arbitration_id
# ImuValid_can9_internal
# AccelerationX_can9_internal
# AccelerationY_can9_internal
# AccelerationZ_can9_internal
# AngularRateX_can9_internal
# AngularRateY_can9_internal
# AngularRateZ_can9_internal
# FixType_can9_internal
# Satellites_can9_internal
# TimeValid_can9_internal
# TimeConfirmed_can9_internal
# Epoch_can9_internal
# PositionValid_can9_internal
# Latitude_can9_internal
# Longitude_can9_internal
# PositionAccuracy_can9_internal
# AltitudeValid_can9_internal
# Altitude_can9_internal
# AltitudeAccuracy_can9_internal
# SpeedValid_can9_internal
# Speed_can9_internal
# SpeedAccuracy_can9_internal
# DistanceValid_can9_internal
# DistanceTrip_can9_internal
#
# Signals in: 00000002_can1_can.parquet
# time
# arbitration_id
# DI_torqueEstimate_can1_can
# DI_gear_can1_can
# DI_brakePedal_can1_can
# DI_vehicleSpeed_can1_can
# DI_gearRequest_can1_can
# DI_torqueInterfaceFailure_can1_can
# DI_torque2Counter_can1_can
# DI_brakePedalState_can1_can
# DI_epbParkRequest_can1_can
# DI_epbInterfaceReady_can1_can
# DI_torque2Checksum_can1_can
# SDM_bcklDrivStatus_can1_can
# SDM_bcklPassStatus_can1_can
# YEAR_can1_can
# CERRD_can1_can
# MONTH_can1_can
# DOOR_STATE_FL_can1_can
# DOOR_STATE_FR_can1_can
# SECOND_can1_can
# DOOR_STATE_RL_can1_can
# Hour_can1_can
# DOOR_STATE_RR_can1_can
# DAY_can1_can
# MINUTE_can1_can
# BOOT_STATE_can1_can
# GTW_updateInProgress_can1_can
# BC_headLightLStatus_can1_can
# DOOR_STATE_FrontTrunk_can1_can
# MCU_transportModeOn_can1_can
# MCU_factoryMode_can1_can
# BC_indicatorRStatus_can1_can
# BC_indicatorLStatus_can1_can
# BC_headLightRStatus_can1_can
# UI_autopilotControlRequest_can1_can
# UI_ulcStalkConfirm_can1_can
# UI_summonHeartbeat_can1_can
# UI_curvSpeedAdaptDisable_can1_can
# UI_dasDeveloper_can1_can
# UI_enableVinAssociation_can1_can
# UI_lssLkaEnabled_can1_can
# UI_lssLdwEnabled_can1_can
# UI_autoSummonEnable_can1_can
# UI_exceptionListEnable_can1_can
# UI_roadCheckDisable_can1_can
# UI_driveOnMapsEnable_can1_can
# UI_handsOnRequirementDisable_can1_can
# UI_forksEnable_can1_can
# UI_fuseLanesDisable_can1_can
# UI_fuseHPPDisable_can1_can
# UI_fuseVehiclesDisable_can1_can
# UI_enableNextGenACC_can1_can
# UI_visionSpeedType_can1_can
# UI_curvatureDatabaseOnly_can1_can
# UI_lssElkEnabled_can1_can
# UI_summonExitType_can1_can
# UI_summonEntryType_can1_can
# UI_selfParkRequest_can1_can
# UI_summonReverseDist_can1_can
# UI_undertakeAssistEnable_can1_can
# UI_adaptiveSetSpeedEnable_can1_can
# UI_drivingSide_can1_can
# UI_enableClipTelemetry_can1_can
# UI_enableTripTelemetry_can1_can
# UI_enableRoadSegmentTelemetry_can1_can
# UI_followNavRouteEnable_can1_can
# UI_ulcSpeedConfig_can1_can
# UI_ulcBlindSpotConfig_can1_can
# UI_autopilotAlwaysOn_can1_can
# UI_accFromZero_can1_can
# UI_alcOffHighwayEnable_can1_can
# UI_validationLoop_can1_can
# UI_ulcOffHighway_can1_can
# UI_enableNavRouteCSA_can1_can
# UI_enableCutinExperiments_can1_can
# UI_source3D_can1_can
# UI_enableVisionOnlyStops_can1_can
# UI_mapSpeedLimitDependency_can1_can
# UI_roadClass_can1_can
# UI_inSuperchargerGeofence_can1_can
# UI_mapSpeedUnits_can1_can
# UI_mapSpeedLimit_can1_can
# UI_mapSpeedLimitType_can1_can
# UI_countryCode_can1_can
# UI_streetCount_can1_can
# UI_gpsRoadMatch_can1_can
# UI_navRouteActive_can1_can
# UI_parallelAutoparkEnabled_can1_can
# UI_perpendicularAutoparkEnabled_can1_can
# UI_nextBranchDist_can1_can
# UI_controlledAccess_can1_can
# UI_nextBranchLeftOffRamp_can1_can
# UI_nextBranchRightOffRamp_can1_can
# UI_rejectLeftLane_can1_can
# UI_rejectRightLane_can1_can
# UI_rejectHPP_can1_can
# UI_rejectNav_can1_can
# UI_rejectLeftFreeSpace_can1_can
# UI_rejectRightFreeSpace_can1_can
# UI_rejectAutosteer_can1_can
# UI_rejectHandsOn_can1_can
# UI_acceptBottsDots_can1_can
# UI_autosteerRestricted_can1_can
# UI_pmmEnabled_can1_can
# UI_scaEnabled_can1_can
# UI_mapDataCounter_can1_can
# UI_mapDataChecksum_can1_can
# UI_csaRoadCurvC2_can1_can
# UI_csaRoadCurvC3_can1_can
# UI_csaRoadCurvRange_can1_can
# UI_csaRoadCurvCounter_can1_can
# UI_csaRoadCurvUsingTspline_can1_can
# UI_csaRoadCurvReserved_can1_can
# UI_csaRoadCurvChecksum_can1_can
# DI_torqueDriver_can1_can
# DI_torque1Counter_can1_can
# DI_torqueMotor_can1_can
# DI_soptState_can1_can
# DI_motorRPM_can1_can
# DI_pedalPos_can1_can
# DI_torque1Checksum_can1_can
# DAS_headlightRequest_can1_can
# DAS_hazardLightRequest_can1_can
# DAS_wiperSpeed_can1_can
# DAS_turnIndicatorRequest_can1_can
# DAS_highLowBeamDecision_can1_can
# DAS_highLowBeamOffReason_can1_can
# DAS_turnIndicatorRequestReason_can1_can
# DAS_bodyControlsCounter_can1_can
# DAS_bodyControlsChecksum_can1_can
# DI_systemState_can1_can
# DI_vehicleHoldState_can1_can
# DI_proximity_can1_can
# DI_driveReady_can1_can
# DI_regenLight_can1_can
# DI_state_can1_can
# DI_cruiseState_can1_can
# DI_analogSpeed_can1_can
# DI_immobilizerState_can1_can
# DI_speedUnits_can1_can
# DI_cruiseSet_can1_can
# DI_aebState_can1_can
# DI_stateCounter_can1_can
# DI_digitalSpeed_can1_can
# DI_stateChecksum_can1_can
#
# Signals in: 00000002_can1_party.parquet
# time
# arbitration_id
# SCCM_steeringAngleCrc_can1_party
# SCCM_steeringAngleCounter_can1_party
# SCCM_supplierID_can1_party
# SCCM_steeringAngleSensorStatus_can1_party
# SCCM_steeringAngle_can1_party
# SCCM_steeringAngleValidity_can1_party
# SCCM_steeringAngleSpeed_can1_party
# SCCM_steeringAngleSensorReservd1_can1_party
# SCCM_steeringAngleSensorReservd2_can1_party
# SCCM_steeringAngleSensorReservd3_can1_party
# VCFRONT_LVPowerStateIndex_can1_party
# VCFRONT_vehiclePowerState_can1_party
# VCFRONT_LVPowerStateCounter_can1_party
# VCFRONT_LVPowerStateChecksum_can1_party
# VCFRONT_cpLVRequest_can1_party
# VCFRONT_epasLVState_can1_party
# VCFRONT_hvcLVRequest_can1_party
# VCFRONT_tasLVState_can1_party
# VCFRONT_pcsLVState_can1_party
# DI_systemStatusChecksum_can1_party
# DI_systemStatusCounter_can1_party
# DI_systemState_can1_party
# DI_brakePedalState_can1_party
# DI_gear_can1_party
# DI_regenLight_can1_party
# DI_immobilizerState_can1_party
# DI_accelPedalPos_can1_party
# DI_tractionControlMode_can1_party
# DI_epbRequest_can1_party
# DI_proximity_can1_party
# DI_keepAliveRequest_can1_party
# DI_trackModeState_can1_party
# DI_speedChecksum_can1_party
# DI_speedCounter_can1_party
# DI_vehicleSpeed_can1_party
# DI_uiSpeed_can1_party
# DI_uiSpeedUnits_can1_party
# IBST_statusChecksum_can1_party
# IBST_statusCounter_can1_party
# IBST_iBoosterStatus_can1_party
# IBST_driverBrakeApply_can1_party
# IBST_internalState_can1_party
# IBST_sInputRodDriver_can1_party
# SCCM_leftStalkCrc_can1_party
# SCCM_leftStalkCounter_can1_party
# SCCM_highBeamStalkStatus_can1_party
# SCCM_washWipeButtonStatus_can1_party
# SCCM_turnIndicatorStalkStatus_can1_party
# SCCM_leftStalkReserved1_can1_party
# VCFRONT_parkLVState_can1_party
# VCFRONT_espLVState_can1_party
# VCFRONT_radcLVState_can1_party
# VCFRONT_hvacCompLVState_can1_party
# VCFRONT_ptcLVRequest_can1_party
# VCFRONT_sccmLVRequest_can1_party
# VCFRONT_tpmsLVRequest_can1_party
# VCFRONT_rcmLVRequest_can1_party
# VCFRONT_iBoosterLVState_can1_party
# VCFRONT_tunerLVRequest_can1_party
# VCFRONT_amplifierLVRequest_can1_party
# VCFRONT_das1HighCurrentLVState_can1_party
# VCFRONT_das2HighCurrentLVState_can1_party
# VCFRONT_diLVRequest_can1_party
# VCFRONT_disLVState_can1_party
# VCFRONT_oilPumpFrontLVState_can1_party
# VCFRONT_oilPumpRearLVRequest_can1_party
# VCFRONT_ocsLVRequest_can1_party
# VCFRONT_vcleftHiCurrentLVState_can1_party
# VCFRONT_vcrightHiCurrentLVState_can1_party
# VCFRONT_uiHiCurrentLVState_can1_party
# VCFRONT_uiAudioLVState_can1_party
# DI_torqueChecksum_can1_party
# DI_torqueCounter_can1_party
# DI_torqueCommand_can1_party
# DI_torqueActual_can1_party
# DI_axleSpeed_can1_party
# DAS_stopLineDist_can1_party
# DAS_trafficLightColor_can1_party
# DAS_offRoadAssist_can1_party
# DAS_slipStart_can1_party
# DAS_driverSteeringWeight_can1_party
# DAS_distanceUnits_can1_party
# DAS_aebEnabled_can1_party
# DAS_adaptiveHeadlights_can1_party
# DAS_autosteerEnabled2_can1_party
# DAS_autosteerEnabled_can1_party
# DAS_fcwSensitivity_can1_party
# DAS_fcwEnabled_can1_party
# DAS_driverAccelerationMode_can1_party
# DAS_obstacleAwareAcceleration_can1_party
# DAS_settingCounter_can1_party
# DAS_settingChecksum_can1_party
# APS_appStatusMonitorState_can1_party
# APS_vehBehaviorState_can1_party
# APS_canMaster_can1_party
# APS_appGpioState_can1_party
# APS_eacInternalState_can1_party
# APS_switchState_can1_party
# APS_apbStatusMonitorState_can1_party
# APS_apbGpioState_can1_party
# APS_statusCounter_can1_party
#
# Signals in: 00000002_can1_vehicle.parquet
# time
# arbitration_id
# SCCM_steeringAngleCrc_can1_vehicle
# SCCM_steeringAngleCounter_can1_vehicle
# SCCM_supplierID_can1_vehicle
# SCCM_steeringAngleSensorStatus_can1_vehicle
# SCCM_steeringAngle_can1_vehicle
# SCCM_steeringAngleValidity_can1_vehicle
# SCCM_steeringAngleSpeed_can1_vehicle
# SCCM_steeringAngleSensorReservd1_can1_vehicle
# SCCM_steeringAngleSensorReservd2_can1_vehicle
# SCCM_steeringAngleSensorReservd3_can1_vehicle
# VCRIGHT_frontLatchStatus_can1_vehicle
# VCRIGHT_rearLatchStatus_can1_vehicle
# VCRIGHT_frontLatchSwitch_can1_vehicle
# VCRIGHT_rearLatchSwitch_can1_vehicle
# VCRIGHT_frontHandlePulled_can1_vehicle
# VCRIGHT_rearHandlePulled_can1_vehicle
# VCRIGHT_frontRelActuatorSwitch_can1_vehicle
# VCRIGHT_rearRelActuatorSwitch_can1_vehicle
# VCRIGHT_frontHandlePWM_can1_vehicle
# VCRIGHT_rearHandlePWM_can1_vehicle
# VCRIGHT_reservedForBackCompat_can1_vehicle
# VCRIGHT_frontHandlePulledPersist_can1_vehicle
# VCRIGHT_frontIntSwitchPressed_can1_vehicle
# VCRIGHT_rearIntSwitchPressed_can1_vehicle
# VCRIGHT_mirrorTiltXPosition_can1_vehicle
# VCRIGHT_mirrorTiltYPosition_can1_vehicle
# VCRIGHT_mirrorState_can1_vehicle
# VCRIGHT_mirrorFoldState_can1_vehicle
# VCRIGHT_trunkLatchStatus_can1_vehicle
# VCRIGHT_mirrorRecallState_can1_vehicle
# VCRIGHT_mirrorDipped_can1_vehicle
# DI_systemStatusChecksum_can1_vehicle
# DI_systemStatusCounter_can1_vehicle
# DI_systemState_can1_vehicle
# DI_brakePedalState_can1_vehicle
# DI_gear_can1_vehicle
# DI_regenLight_can1_vehicle
# DI_immobilizerState_can1_vehicle
# DI_accelPedalPos_can1_vehicle
# DI_tractionControlMode_can1_vehicle
# DI_epbRequest_can1_vehicle
# DI_proximity_can1_vehicle
# DI_keepAliveRequest_can1_vehicle
# DI_trackModeState_can1_vehicle
# SCCM_rightStalkCrc_can1_vehicle
# SCCM_rightStalkCounter_can1_vehicle
# SCCM_rightStalkStatus_can1_vehicle
# SCCM_rightStalkReserved1_can1_vehicle
# SCCM_parkButtonStatus_can1_vehicle
# SCCM_rightStalkReserved2_can1_vehicle
# SCCM_leftStalkCrc_can1_vehicle
# SCCM_leftStalkCounter_can1_vehicle
# SCCM_highBeamStalkStatus_can1_vehicle
# SCCM_washWipeButtonStatus_can1_vehicle
# SCCM_turnIndicatorStalkStatus_can1_vehicle
# SCCM_leftStalkReserved1_can1_vehicle
# VCLEFT_switchStatusIndex_can1_vehicle
# VCLEFT_swcLeftTiltRight_can1_vehicle
# VCLEFT_swcLeftPressed_can1_vehicle
# VCLEFT_swcRightTiltLeft_can1_vehicle
# VCLEFT_swcRightTiltRight_can1_vehicle
# VCLEFT_swcRightPressed_can1_vehicle
# VCLEFT_swcLeftTiltLeft_can1_vehicle
# VCLEFT_swcLeftScrollTicks_can1_vehicle
# VCLEFT_swcRightScrollTicks_can1_vehicle
# VCLEFT_btnWindowUpLR_can1_vehicle
# VCLEFT_btnWindowAutoUpLR_can1_vehicle
# VCLEFT_btnWindowDownLR_can1_vehicle
# VCLEFT_btnWindowAutoDownLR_can1_vehicle
# VCRIGHT_loadShedPriority_can1_vehicle
# VCRIGHT_vehiclePowerStateDBG_can1_vehicle
# VCRIGHT_swEnStatus_can1_vehicle
# VCRIGHT_rearDefrostState_can1_vehicle
# VCRIGHT_mirrorHeatState_can1_vehicle
# VCRIGHT_OTAState_can1_vehicle
# VCRIGHT_5AVoltage_can1_vehicle
# VCRIGHT_vbatProt_can1_vehicle
# VCRIGHT_footwellLightCurrent_can1_vehicle
# VCRIGHT_pcbaTemperature_can1_vehicle
# VCFRONT_indicatorLeftRequest_can1_vehicle
# VCFRONT_indicatorRightRequest_can1_vehicle
# VCFRONT_hazardLightRequest_can1_vehicle
# VCFRONT_ambientLightingBrightnes_can1_vehicle
# VCFRONT_switchLightingBrightness_can1_vehicle
# VCFRONT_courtesyLightingRequest_can1_vehicle
# VCFRONT_approachLightingRequest_can1_vehicle
# VCFRONT_seeYouHomeLightingReq_can1_vehicle
# VCFRONT_hazardSwitchBacklight_can1_vehicle
# VCFRONT_lowBeamLeftStatus_can1_vehicle
# VCFRONT_lowBeamRightStatus_can1_vehicle
# VCFRONT_highBeamLeftStatus_can1_vehicle
# VCFRONT_highBeamRightStatus_can1_vehicle
# VCFRONT_DRLLeftStatus_can1_vehicle
# VCFRONT_DRLRightStatus_can1_vehicle
# VCFRONT_fogLeftStatus_can1_vehicle
# VCFRONT_fogRightStatus_can1_vehicle
# VCFRONT_sideMarkersStatus_can1_vehicle
# VCFRONT_sideRepeaterLeftStatus_can1_vehicle
# VCFRONT_sideRepeaterRightStatus_can1_vehicle
# VCFRONT_turnSignalLeftStatus_can1_vehicle
# VCFRONT_turnSignalRightStatus_can1_vehicle
# VCFRONT_parkLeftStatus_can1_vehicle
# VCFRONT_parkRightStatus_can1_vehicle
# VCFRONT_highBeamSwitchActive_can1_vehicle
# VCFRONT_simLatchingStalk_can1_vehicle
# VCFRONT_lowBeamsOnForDRL_can1_vehicle
# VCFRONT_lowBeamsCalibrated_can1_vehicle
# VCLEFT_frontLatchStatus_can1_vehicle
# VCLEFT_rearLatchStatus_can1_vehicle
# VCLEFT_frontLatchSwitch_can1_vehicle
# VCLEFT_rearLatchSwitch_can1_vehicle
# VCLEFT_frontHandlePulled_can1_vehicle
# VCLEFT_rearHandlePulled_can1_vehicle
# VCLEFT_frontRelActuatorSwitch_can1_vehicle
# VCLEFT_rearRelActuatorSwitch_can1_vehicle
# VCLEFT_frontHandlePWM_can1_vehicle
# VCLEFT_rearHandlePWM_can1_vehicle
# VCLEFT_frontIntSwitchPressed_can1_vehicle
# VCLEFT_rearIntSwitchPressed_can1_vehicle
# VCLEFT_mirrorTiltXPosition_can1_vehicle
# VCLEFT_mirrorTiltYPosition_can1_vehicle
# VCLEFT_mirrorState_can1_vehicle
# VCLEFT_mirrorFoldState_can1_vehicle
# VCLEFT_mirrorRecallState_can1_vehicle
# VCLEFT_mirrorHeatState_can1_vehicle
# VCLEFT_mirrorDipped_can1_vehicle
# VCLEFT_frontHandlePulledPersist_can1_vehicle
# SpdCtrlLvr_Stat_can1_vehicle
# VSL_Enbl_Rq_can1_vehicle
# SpdCtrlLvrStat_Inv_can1_vehicle
# DTR_Dist_Rq_can1_vehicle
# TurnIndLvr_Stat_can1_vehicle
# HiBmLvr_Stat_can1_vehicle
# WprWashSw_Psd_can1_vehicle
# WprWash_R_Sw_Posn_V2_can1_vehicle
# StW_Lvr_Stat_can1_vehicle
# StW_Cond_Flt_can1_vehicle
# StW_Cond_Psd_can1_vehicle
# HrnSw_Psd_can1_vehicle
# StW_Sw00_Psd_can1_vehicle
# StW_Sw01_Psd_can1_vehicle
# StW_Sw02_Psd_can1_vehicle
# StW_Sw03_Psd_can1_vehicle
# StW_Sw04_Psd_can1_vehicle
# StW_Sw05_Psd_can1_vehicle
# StW_Sw06_Psd_can1_vehicle
# StW_Sw07_Psd_can1_vehicle
# StW_Sw08_Psd_can1_vehicle
# StW_Sw09_Psd_can1_vehicle
# StW_Sw10_Psd_can1_vehicle
# StW_Sw11_Psd_can1_vehicle
# StW_Sw12_Psd_can1_vehicle
# StW_Sw13_Psd_can1_vehicle
# StW_Sw14_Psd_can1_vehicle
# StW_Sw15_Psd_can1_vehicle
# WprSw6Posn_can1_vehicle
# MC_STW_ACTN_RQ_can1_vehicle
# CRC_STW_ACTN_RQ_can1_vehicle
# VCLEFT_hornSwitchPressed_can1_vehicle
# VCLEFT_hazardButtonPressed_can1_vehicle
# VCLEFT_driverPresent_can1_vehicle
# VCLEFT_rightMirrorTilt_can1_vehicle
# VCLEFT_frontSeatTrackBack_can1_vehicle
# VCLEFT_frontSeatTrackForward_can1_vehicle
# VCLEFT_frontSeatTiltDown_can1_vehicle
# VCLEFT_frontSeatTiltUp_can1_vehicle
# VCLEFT_frontSeatLiftDown_can1_vehicle
# VCLEFT_frontSeatLiftUp_can1_vehicle
# VCLEFT_frontSeatBackrestBack_can1_vehicle
# VCLEFT_frontSeatBackrestForward_can1_vehicle
# VCLEFT_frontSeatLumbarDown_can1_vehicle
# VCLEFT_frontSeatLumbarUp_can1_vehicle
# VCLEFT_frontSeatLumbarIn_can1_vehicle
# VCLEFT_frontSeatLumbarOut_can1_vehicle
# VCLEFT_btnWindowSwPackUpLF_can1_vehicle
# VCLEFT_btnWindowSwPackAutoUpLF_can1_vehicle
# VCLEFT_btnWindowSwPackDownLF_can1_vehicle
# VCLEFT_btnWindowSwPackAutoDownLF_can1_vehicle
# VCLEFT_btnWindowSwPackUpLR_can1_vehicle
# VCLEFT_btnWindowSwPackAutoUpLR_can1_vehicle
# VCLEFT_btnWindowSwPackDownLR_can1_vehicle
# VCLEFT_btnWindowSwPackAutoDownLR_can1_vehicle
# VCLEFT_btnWindowSwPackUpRF_can1_vehicle
# VCLEFT_btnWindowSwPackAutoUpRF_can1_vehicle
# VCLEFT_btnWindowSwPackDownRF_can1_vehicle
# VCLEFT_btnWindowSwPackAutoDownRF_can1_vehicle
# VCLEFT_btnWindowSwPackUpRR_can1_vehicle
# VCLEFT_btnWindowSwPackAutoUpRR_can1_vehicle
# VCLEFT_btnWindowSwPackDownRR_can1_vehicle
# VCLEFT_btnWindowSwPackAutoDownRR_can1_vehicle
# VCLEFT_frontBuckleSwitch_can1_vehicle
# VCLEFT_frontOccupancySwitch_can1_vehicle
# VCLEFT_rearLeftBuckleSwitch_can1_vehicle
# VCLEFT_rearCenterOccupancySwitch_can1_vehicle
# VCLEFT_rearLeftOccupancySwitch_can1_vehicle
# VCLEFT_rearRightOccupancySwitch_can1_vehicle
# VCLEFT_brakePressed_can1_vehicle
# VCLEFT_rearHVACButtonPressed_can1_vehicle
# DAS_headlightRequest_can1_vehicle
# DAS_hazardLightRequest_can1_vehicle
# DAS_wiperSpeed_can1_vehicle
# DAS_turnIndicatorRequest_can1_vehicle
# DAS_highLowBeamDecision_can1_vehicle
# DAS_heaterRequest_can1_vehicle
# DAS_turnIndicatorRequestReason_can1_vehicle
# DAS_autopilotActive_can1_vehicle
# DAS_accActive_can1_vehicle
# DAS_bodyControlsCounter_can1_vehicle
# DAS_bodyControlsChecksum_can1_vehicle
#
# Signals in: 00000002_can9_internal.parquet
# time
# arbitration_id
# ImuValid_can9_internal
# AccelerationX_can9_internal
# AccelerationY_can9_internal
# AccelerationZ_can9_internal
# AngularRateX_can9_internal
# AngularRateY_can9_internal
# AngularRateZ_can9_internal
# FixType_can9_internal
# Satellites_can9_internal
# TimeValid_can9_internal
# TimeConfirmed_can9_internal
# Epoch_can9_internal
# PositionValid_can9_internal
# Latitude_can9_internal
# Longitude_can9_internal
# PositionAccuracy_can9_internal
# AltitudeValid_can9_internal
# Altitude_can9_internal
# AltitudeAccuracy_can9_internal
# SpeedValid_can9_internal
# Speed_can9_internal
# SpeedAccuracy_can9_internal
# DistanceValid_can9_internal
# DistanceTrip_can9_internal
#
# Signals in: 00000003_can1_can.parquet
# time
# arbitration_id
# DAS_headlightRequest_can1_can
# DAS_hazardLightRequest_can1_can
# DAS_wiperSpeed_can1_can
# DAS_turnIndicatorRequest_can1_can
# DAS_highLowBeamDecision_can1_can
# DAS_highLowBeamOffReason_can1_can
# DAS_turnIndicatorRequestReason_can1_can
# DAS_bodyControlsCounter_can1_can
# DAS_bodyControlsChecksum_can1_can
# DI_torqueEstimate_can1_can
# DI_gear_can1_can
# DI_brakePedal_can1_can
# DI_vehicleSpeed_can1_can
# DI_gearRequest_can1_can
# DI_torqueInterfaceFailure_can1_can
# DI_torque2Counter_can1_can
# DI_brakePedalState_can1_can
# DI_epbParkRequest_can1_can
# DI_epbInterfaceReady_can1_can
# DI_torque2Checksum_can1_can
# DI_torqueDriver_can1_can
# DI_torque1Counter_can1_can
# DI_torqueMotor_can1_can
# DI_soptState_can1_can
# DI_motorRPM_can1_can
# DI_pedalPos_can1_can
# DI_torque1Checksum_can1_can
# SDM_bcklDrivStatus_can1_can
# SDM_bcklPassStatus_can1_can
# UI_autopilotControlRequest_can1_can
# UI_ulcStalkConfirm_can1_can
# UI_summonHeartbeat_can1_can
# UI_curvSpeedAdaptDisable_can1_can
# UI_dasDeveloper_can1_can
# UI_enableVinAssociation_can1_can
# UI_lssLkaEnabled_can1_can
# UI_lssLdwEnabled_can1_can
# UI_autoSummonEnable_can1_can
# UI_exceptionListEnable_can1_can
# UI_roadCheckDisable_can1_can
# UI_driveOnMapsEnable_can1_can
# UI_handsOnRequirementDisable_can1_can
# UI_forksEnable_can1_can
# UI_fuseLanesDisable_can1_can
# UI_fuseHPPDisable_can1_can
# UI_fuseVehiclesDisable_can1_can
# UI_enableNextGenACC_can1_can
# UI_visionSpeedType_can1_can
# UI_curvatureDatabaseOnly_can1_can
# UI_lssElkEnabled_can1_can
# UI_summonExitType_can1_can
# UI_summonEntryType_can1_can
# UI_selfParkRequest_can1_can
# UI_summonReverseDist_can1_can
# UI_undertakeAssistEnable_can1_can
# UI_adaptiveSetSpeedEnable_can1_can
# UI_drivingSide_can1_can
# UI_enableClipTelemetry_can1_can
# UI_enableTripTelemetry_can1_can
# UI_enableRoadSegmentTelemetry_can1_can
# UI_followNavRouteEnable_can1_can
# UI_ulcSpeedConfig_can1_can
# UI_ulcBlindSpotConfig_can1_can
# UI_autopilotAlwaysOn_can1_can
# UI_accFromZero_can1_can
# UI_alcOffHighwayEnable_can1_can
# UI_validationLoop_can1_can
# UI_ulcOffHighway_can1_can
# UI_enableNavRouteCSA_can1_can
# UI_enableCutinExperiments_can1_can
# UI_source3D_can1_can
# UI_enableVisionOnlyStops_can1_can
# YEAR_can1_can
# CERRD_can1_can
# MONTH_can1_can
# DOOR_STATE_FL_can1_can
# DOOR_STATE_FR_can1_can
# SECOND_can1_can
# DOOR_STATE_RL_can1_can
# Hour_can1_can
# DOOR_STATE_RR_can1_can
# DAY_can1_can
# MINUTE_can1_can
# BOOT_STATE_can1_can
# GTW_updateInProgress_can1_can
# BC_headLightLStatus_can1_can
# DOOR_STATE_FrontTrunk_can1_can
# MCU_transportModeOn_can1_can
# MCU_factoryMode_can1_can
# BC_indicatorRStatus_can1_can
# BC_indicatorLStatus_can1_can
# BC_headLightRStatus_can1_can
# UI_mapSpeedLimitDependency_can1_can
# UI_roadClass_can1_can
# UI_inSuperchargerGeofence_can1_can
# UI_mapSpeedUnits_can1_can
# UI_mapSpeedLimit_can1_can
# UI_mapSpeedLimitType_can1_can
# UI_countryCode_can1_can
# UI_streetCount_can1_can
# UI_gpsRoadMatch_can1_can
# UI_navRouteActive_can1_can
# UI_parallelAutoparkEnabled_can1_can
# UI_perpendicularAutoparkEnabled_can1_can
# UI_nextBranchDist_can1_can
# UI_controlledAccess_can1_can
# UI_nextBranchLeftOffRamp_can1_can
# UI_nextBranchRightOffRamp_can1_can
# UI_rejectLeftLane_can1_can
# UI_rejectRightLane_can1_can
# UI_rejectHPP_can1_can
# UI_rejectNav_can1_can
# UI_rejectLeftFreeSpace_can1_can
# UI_rejectRightFreeSpace_can1_can
# UI_rejectAutosteer_can1_can
# UI_rejectHandsOn_can1_can
# UI_acceptBottsDots_can1_can
# UI_autosteerRestricted_can1_can
# UI_pmmEnabled_can1_can
# UI_scaEnabled_can1_can
# UI_mapDataCounter_can1_can
# UI_mapDataChecksum_can1_can
# UI_csaRoadCurvC2_can1_can
# UI_csaRoadCurvC3_can1_can
# UI_csaRoadCurvRange_can1_can
# UI_csaRoadCurvCounter_can1_can
# UI_csaRoadCurvUsingTspline_can1_can
# UI_csaRoadCurvReserved_can1_can
# UI_csaRoadCurvChecksum_can1_can
# DI_systemState_can1_can
# DI_vehicleHoldState_can1_can
# DI_proximity_can1_can
# DI_driveReady_can1_can
# DI_regenLight_can1_can
# DI_state_can1_can
# DI_cruiseState_can1_can
# DI_analogSpeed_can1_can
# DI_immobilizerState_can1_can
# DI_speedUnits_can1_can
# DI_cruiseSet_can1_can
# DI_aebState_can1_can
# DI_stateCounter_can1_can
# DI_digitalSpeed_can1_can
# DI_stateChecksum_can1_can
# MCU_clusterReadyForPowerOff_can1_can
# MCU_clusterReadyForDrive_can1_can
# MCU_clusterBacklightOn_can1_can
# MCU_clusterBrightnessLevel_can1_can
#
# Signals in: 00000003_can1_party.parquet
# time
# arbitration_id
# IBST_statusChecksum_can1_party
# IBST_statusCounter_can1_party
# IBST_iBoosterStatus_can1_party
# IBST_driverBrakeApply_can1_party
# IBST_internalState_can1_party
# IBST_sInputRodDriver_can1_party
# SCCM_steeringAngleCrc_can1_party
# SCCM_steeringAngleCounter_can1_party
# SCCM_supplierID_can1_party
# SCCM_steeringAngleSensorStatus_can1_party
# SCCM_steeringAngle_can1_party
# SCCM_steeringAngleValidity_can1_party
# SCCM_steeringAngleSpeed_can1_party
# SCCM_steeringAngleSensorReservd1_can1_party
# SCCM_steeringAngleSensorReservd2_can1_party
# SCCM_steeringAngleSensorReservd3_can1_party
# DI_systemStatusChecksum_can1_party
# DI_systemStatusCounter_can1_party
# DI_systemState_can1_party
# DI_brakePedalState_can1_party
# DI_gear_can1_party
# DI_regenLight_can1_party
# DI_immobilizerState_can1_party
# DI_accelPedalPos_can1_party
# DI_tractionControlMode_can1_party
# DI_epbRequest_can1_party
# DI_proximity_can1_party
# DI_keepAliveRequest_can1_party
# DI_trackModeState_can1_party
# DI_speedChecksum_can1_party
# DI_speedCounter_can1_party
# DI_vehicleSpeed_can1_party
# DI_uiSpeed_can1_party
# DI_uiSpeedUnits_can1_party
# DI_torqueChecksum_can1_party
# DI_torqueCounter_can1_party
# DI_torqueCommand_can1_party
# DI_torqueActual_can1_party
# DI_axleSpeed_can1_party
# VCFRONT_LVPowerStateIndex_can1_party
# VCFRONT_vehiclePowerState_can1_party
# VCFRONT_LVPowerStateCounter_can1_party
# VCFRONT_LVPowerStateChecksum_can1_party
# VCFRONT_parkLVState_can1_party
# VCFRONT_espLVState_can1_party
# VCFRONT_radcLVState_can1_party
# VCFRONT_hvacCompLVState_can1_party
# VCFRONT_ptcLVRequest_can1_party
# VCFRONT_sccmLVRequest_can1_party
# VCFRONT_tpmsLVRequest_can1_party
# VCFRONT_rcmLVRequest_can1_party
# VCFRONT_iBoosterLVState_can1_party
# VCFRONT_tunerLVRequest_can1_party
# VCFRONT_amplifierLVRequest_can1_party
# VCFRONT_das1HighCurrentLVState_can1_party
# VCFRONT_das2HighCurrentLVState_can1_party
# VCFRONT_diLVRequest_can1_party
# VCFRONT_disLVState_can1_party
# VCFRONT_oilPumpFrontLVState_can1_party
# VCFRONT_oilPumpRearLVRequest_can1_party
# VCFRONT_ocsLVRequest_can1_party
# VCFRONT_vcleftHiCurrentLVState_can1_party
# VCFRONT_vcrightHiCurrentLVState_can1_party
# VCFRONT_uiHiCurrentLVState_can1_party
# VCFRONT_uiAudioLVState_can1_party
# SCCM_leftStalkCrc_can1_party
# SCCM_leftStalkCounter_can1_party
# SCCM_highBeamStalkStatus_can1_party
# SCCM_washWipeButtonStatus_can1_party
# SCCM_turnIndicatorStalkStatus_can1_party
# SCCM_leftStalkReserved1_can1_party
# VCFRONT_cpLVRequest_can1_party
# VCFRONT_epasLVState_can1_party
# VCFRONT_hvcLVRequest_can1_party
# VCFRONT_tasLVState_can1_party
# VCFRONT_pcsLVState_can1_party
# DAS_stopLineDist_can1_party
# DAS_trafficLightColor_can1_party
# DAS_offRoadAssist_can1_party
# DAS_slipStart_can1_party
# DAS_driverSteeringWeight_can1_party
# DAS_distanceUnits_can1_party
# DAS_aebEnabled_can1_party
# DAS_adaptiveHeadlights_can1_party
# DAS_autosteerEnabled2_can1_party
# DAS_autosteerEnabled_can1_party
# DAS_fcwSensitivity_can1_party
# DAS_fcwEnabled_can1_party
# DAS_driverAccelerationMode_can1_party
# DAS_obstacleAwareAcceleration_can1_party
# DAS_settingCounter_can1_party
# DAS_settingChecksum_can1_party
# APS_appStatusMonitorState_can1_party
# APS_vehBehaviorState_can1_party
# APS_canMaster_can1_party
# APS_appGpioState_can1_party
# APS_eacInternalState_can1_party
# APS_switchState_can1_party
# APS_apbStatusMonitorState_can1_party
# APS_apbGpioState_can1_party
# APS_statusCounter_can1_party
#
# Signals in: 00000003_can1_vehicle.parquet
# time
# arbitration_id
# DAS_headlightRequest_can1_vehicle
# DAS_hazardLightRequest_can1_vehicle
# DAS_wiperSpeed_can1_vehicle
# DAS_turnIndicatorRequest_can1_vehicle
# DAS_highLowBeamDecision_can1_vehicle
# DAS_heaterRequest_can1_vehicle
# DAS_turnIndicatorRequestReason_can1_vehicle
# DAS_autopilotActive_can1_vehicle
# DAS_accActive_can1_vehicle
# DAS_bodyControlsCounter_can1_vehicle
# DAS_bodyControlsChecksum_can1_vehicle
# SCCM_steeringAngleCrc_can1_vehicle
# SCCM_steeringAngleCounter_can1_vehicle
# SCCM_supplierID_can1_vehicle
# SCCM_steeringAngleSensorStatus_can1_vehicle
# SCCM_steeringAngle_can1_vehicle
# SCCM_steeringAngleValidity_can1_vehicle
# SCCM_steeringAngleSpeed_can1_vehicle
# SCCM_steeringAngleSensorReservd1_can1_vehicle
# SCCM_steeringAngleSensorReservd2_can1_vehicle
# SCCM_steeringAngleSensorReservd3_can1_vehicle
# DI_systemStatusChecksum_can1_vehicle
# DI_systemStatusCounter_can1_vehicle
# DI_systemState_can1_vehicle
# DI_brakePedalState_can1_vehicle
# DI_gear_can1_vehicle
# DI_regenLight_can1_vehicle
# DI_immobilizerState_can1_vehicle
# DI_accelPedalPos_can1_vehicle
# DI_tractionControlMode_can1_vehicle
# DI_epbRequest_can1_vehicle
# DI_proximity_can1_vehicle
# DI_keepAliveRequest_can1_vehicle
# DI_trackModeState_can1_vehicle
# VCLEFT_switchStatusIndex_can1_vehicle
# VCLEFT_swcLeftTiltRight_can1_vehicle
# VCLEFT_swcLeftPressed_can1_vehicle
# VCLEFT_swcRightTiltLeft_can1_vehicle
# VCLEFT_swcRightTiltRight_can1_vehicle
# VCLEFT_swcRightPressed_can1_vehicle
# VCLEFT_swcLeftTiltLeft_can1_vehicle
# VCLEFT_swcLeftScrollTicks_can1_vehicle
# VCLEFT_swcRightScrollTicks_can1_vehicle
# VCLEFT_btnWindowUpLR_can1_vehicle
# VCLEFT_btnWindowAutoUpLR_can1_vehicle
# VCLEFT_btnWindowDownLR_can1_vehicle
# VCLEFT_btnWindowAutoDownLR_can1_vehicle
# VCRIGHT_loadShedPriority_can1_vehicle
# VCRIGHT_vehiclePowerStateDBG_can1_vehicle
# VCRIGHT_swEnStatus_can1_vehicle
# VCRIGHT_rearDefrostState_can1_vehicle
# VCRIGHT_mirrorHeatState_can1_vehicle
# VCRIGHT_OTAState_can1_vehicle
# VCRIGHT_5AVoltage_can1_vehicle
# VCRIGHT_vbatProt_can1_vehicle
# VCRIGHT_footwellLightCurrent_can1_vehicle
# VCRIGHT_pcbaTemperature_can1_vehicle
# SCCM_leftStalkCrc_can1_vehicle
# SCCM_leftStalkCounter_can1_vehicle
# SCCM_highBeamStalkStatus_can1_vehicle
# SCCM_washWipeButtonStatus_can1_vehicle
# SCCM_turnIndicatorStalkStatus_can1_vehicle
# SCCM_leftStalkReserved1_can1_vehicle
# VCFRONT_indicatorLeftRequest_can1_vehicle
# VCFRONT_indicatorRightRequest_can1_vehicle
# VCFRONT_hazardLightRequest_can1_vehicle
# VCFRONT_ambientLightingBrightnes_can1_vehicle
# VCFRONT_switchLightingBrightness_can1_vehicle
# VCFRONT_courtesyLightingRequest_can1_vehicle
# VCFRONT_approachLightingRequest_can1_vehicle
# VCFRONT_seeYouHomeLightingReq_can1_vehicle
# VCFRONT_hazardSwitchBacklight_can1_vehicle
# VCFRONT_lowBeamLeftStatus_can1_vehicle
# VCFRONT_lowBeamRightStatus_can1_vehicle
# VCFRONT_highBeamLeftStatus_can1_vehicle
# VCFRONT_highBeamRightStatus_can1_vehicle
# VCFRONT_DRLLeftStatus_can1_vehicle
# VCFRONT_DRLRightStatus_can1_vehicle
# VCFRONT_fogLeftStatus_can1_vehicle
# VCFRONT_fogRightStatus_can1_vehicle
# VCFRONT_sideMarkersStatus_can1_vehicle
# VCFRONT_sideRepeaterLeftStatus_can1_vehicle
# VCFRONT_sideRepeaterRightStatus_can1_vehicle
# VCFRONT_turnSignalLeftStatus_can1_vehicle
# VCFRONT_turnSignalRightStatus_can1_vehicle
# VCFRONT_parkLeftStatus_can1_vehicle
# VCFRONT_parkRightStatus_can1_vehicle
# VCFRONT_highBeamSwitchActive_can1_vehicle
# VCFRONT_simLatchingStalk_can1_vehicle
# VCFRONT_lowBeamsOnForDRL_can1_vehicle
# VCFRONT_lowBeamsCalibrated_can1_vehicle
# VCLEFT_frontLatchStatus_can1_vehicle
# VCLEFT_rearLatchStatus_can1_vehicle
# VCLEFT_frontLatchSwitch_can1_vehicle
# VCLEFT_rearLatchSwitch_can1_vehicle
# VCLEFT_frontHandlePulled_can1_vehicle
# VCLEFT_rearHandlePulled_can1_vehicle
# VCLEFT_frontRelActuatorSwitch_can1_vehicle
# VCLEFT_rearRelActuatorSwitch_can1_vehicle
# VCLEFT_frontHandlePWM_can1_vehicle
# VCLEFT_rearHandlePWM_can1_vehicle
# VCLEFT_frontIntSwitchPressed_can1_vehicle
# VCLEFT_rearIntSwitchPressed_can1_vehicle
# VCLEFT_mirrorTiltXPosition_can1_vehicle
# VCLEFT_mirrorTiltYPosition_can1_vehicle
# VCLEFT_mirrorState_can1_vehicle
# VCLEFT_mirrorFoldState_can1_vehicle
# VCLEFT_mirrorRecallState_can1_vehicle
# VCLEFT_mirrorHeatState_can1_vehicle
# VCLEFT_mirrorDipped_can1_vehicle
# VCLEFT_frontHandlePulledPersist_can1_vehicle
# VCLEFT_hornSwitchPressed_can1_vehicle
# VCLEFT_hazardButtonPressed_can1_vehicle
# VCLEFT_driverPresent_can1_vehicle
# VCLEFT_rightMirrorTilt_can1_vehicle
# VCLEFT_frontSeatTrackBack_can1_vehicle
# VCLEFT_frontSeatTrackForward_can1_vehicle
# VCLEFT_frontSeatTiltDown_can1_vehicle
# VCLEFT_frontSeatTiltUp_can1_vehicle
# VCLEFT_frontSeatLiftDown_can1_vehicle
# VCLEFT_frontSeatLiftUp_can1_vehicle
# VCLEFT_frontSeatBackrestBack_can1_vehicle
# VCLEFT_frontSeatBackrestForward_can1_vehicle
# VCLEFT_frontSeatLumbarDown_can1_vehicle
# VCLEFT_frontSeatLumbarUp_can1_vehicle
# VCLEFT_frontSeatLumbarIn_can1_vehicle
# VCLEFT_frontSeatLumbarOut_can1_vehicle
# VCLEFT_btnWindowSwPackUpLF_can1_vehicle
# VCLEFT_btnWindowSwPackAutoUpLF_can1_vehicle
# VCLEFT_btnWindowSwPackDownLF_can1_vehicle
# VCLEFT_btnWindowSwPackAutoDownLF_can1_vehicle
# VCLEFT_btnWindowSwPackUpLR_can1_vehicle
# VCLEFT_btnWindowSwPackAutoUpLR_can1_vehicle
# VCLEFT_btnWindowSwPackDownLR_can1_vehicle
# VCLEFT_btnWindowSwPackAutoDownLR_can1_vehicle
# VCLEFT_btnWindowSwPackUpRF_can1_vehicle
# VCLEFT_btnWindowSwPackAutoUpRF_can1_vehicle
# VCLEFT_btnWindowSwPackDownRF_can1_vehicle
# VCLEFT_btnWindowSwPackAutoDownRF_can1_vehicle
# VCLEFT_btnWindowSwPackUpRR_can1_vehicle
# VCLEFT_btnWindowSwPackAutoUpRR_can1_vehicle
# VCLEFT_btnWindowSwPackDownRR_can1_vehicle
# VCLEFT_btnWindowSwPackAutoDownRR_can1_vehicle
# VCLEFT_frontBuckleSwitch_can1_vehicle
# VCLEFT_frontOccupancySwitch_can1_vehicle
# VCLEFT_rearLeftBuckleSwitch_can1_vehicle
# VCLEFT_rearCenterOccupancySwitch_can1_vehicle
# VCLEFT_rearLeftOccupancySwitch_can1_vehicle
# VCLEFT_rearRightOccupancySwitch_can1_vehicle
# VCLEFT_brakePressed_can1_vehicle
# VCLEFT_rearHVACButtonPressed_can1_vehicle
# SCCM_rightStalkCrc_can1_vehicle
# SCCM_rightStalkCounter_can1_vehicle
# SCCM_rightStalkStatus_can1_vehicle
# SCCM_rightStalkReserved1_can1_vehicle
# SCCM_parkButtonStatus_can1_vehicle
# SCCM_rightStalkReserved2_can1_vehicle
# VCRIGHT_frontLatchStatus_can1_vehicle
# VCRIGHT_rearLatchStatus_can1_vehicle
# VCRIGHT_frontLatchSwitch_can1_vehicle
# VCRIGHT_rearLatchSwitch_can1_vehicle
# VCRIGHT_frontHandlePulled_can1_vehicle
# VCRIGHT_rearHandlePulled_can1_vehicle
# VCRIGHT_frontRelActuatorSwitch_can1_vehicle
# VCRIGHT_rearRelActuatorSwitch_can1_vehicle
# VCRIGHT_frontHandlePWM_can1_vehicle
# VCRIGHT_rearHandlePWM_can1_vehicle
# VCRIGHT_reservedForBackCompat_can1_vehicle
# VCRIGHT_frontHandlePulledPersist_can1_vehicle
# VCRIGHT_frontIntSwitchPressed_can1_vehicle
# VCRIGHT_rearIntSwitchPressed_can1_vehicle
# VCRIGHT_mirrorTiltXPosition_can1_vehicle
# VCRIGHT_mirrorTiltYPosition_can1_vehicle
# VCRIGHT_mirrorState_can1_vehicle
# VCRIGHT_mirrorFoldState_can1_vehicle
# VCRIGHT_trunkLatchStatus_can1_vehicle
# VCRIGHT_mirrorRecallState_can1_vehicle
# VCRIGHT_mirrorDipped_can1_vehicle
# SpdCtrlLvr_Stat_can1_vehicle
# VSL_Enbl_Rq_can1_vehicle
# SpdCtrlLvrStat_Inv_can1_vehicle
# DTR_Dist_Rq_can1_vehicle
# TurnIndLvr_Stat_can1_vehicle
# HiBmLvr_Stat_can1_vehicle
# WprWashSw_Psd_can1_vehicle
# WprWash_R_Sw_Posn_V2_can1_vehicle
# StW_Lvr_Stat_can1_vehicle
# StW_Cond_Flt_can1_vehicle
# StW_Cond_Psd_can1_vehicle
# HrnSw_Psd_can1_vehicle
# StW_Sw00_Psd_can1_vehicle
# StW_Sw01_Psd_can1_vehicle
# StW_Sw02_Psd_can1_vehicle
# StW_Sw03_Psd_can1_vehicle
# StW_Sw04_Psd_can1_vehicle
# StW_Sw05_Psd_can1_vehicle
# StW_Sw06_Psd_can1_vehicle
# StW_Sw07_Psd_can1_vehicle
# StW_Sw08_Psd_can1_vehicle
# StW_Sw09_Psd_can1_vehicle
# StW_Sw10_Psd_can1_vehicle
# StW_Sw11_Psd_can1_vehicle
# StW_Sw12_Psd_can1_vehicle
# StW_Sw13_Psd_can1_vehicle
# StW_Sw14_Psd_can1_vehicle
# StW_Sw15_Psd_can1_vehicle
# WprSw6Posn_can1_vehicle
# MC_STW_ACTN_RQ_can1_vehicle
# CRC_STW_ACTN_RQ_can1_vehicle
#
# Signals in: 00000003_can9_internal.parquet
# time
# arbitration_id
# AltitudeValid_can9_internal
# Altitude_can9_internal
# AltitudeAccuracy_can9_internal
# SpeedValid_can9_internal
# Speed_can9_internal
# SpeedAccuracy_can9_internal
# DistanceValid_can9_internal
# DistanceTrip_can9_internal
# ImuValid_can9_internal
# AccelerationX_can9_internal
# AccelerationY_can9_internal
# AccelerationZ_can9_internal
# AngularRateX_can9_internal
# AngularRateY_can9_internal
# AngularRateZ_can9_internal
# FixType_can9_internal
# Satellites_can9_internal
# TimeValid_can9_internal
# TimeConfirmed_can9_internal
# Epoch_can9_internal
# PositionValid_can9_internal
# Latitude_can9_internal
# Longitude_can9_internal
# PositionAccuracy_can9_internal

# %%
# --- (Optional): Save all signals from all files to a master registry CSV ---
rows = []
for file, cols in all_signals.items():
    for col in cols:
        rows.append({"parquet_file": file, "signal": col})

registry = pd.DataFrame(rows)
registry.to_csv(REGISTRY_DIR/ "all_signals_registry.csv", index=False)
print("\nAll signals from all files exported to all_signals_registry.csv")
# Out:
# All signals from all files exported to all_signals_registry.csv
